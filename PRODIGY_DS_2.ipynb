# %% [markdown]
# # PRODIGY INFOTECH VIRTUAL INTERNSHIP - DS TASK 2
# Performing Data Cleaning and EDA on the custom Temprature Dataset of India. took my own dataset from kaggle and performed EDA and Data cleaning on it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/TEMP_ANNUAL_SEASONAL_MEAN.csv")
df.head()
# Out:
#      YEAR ANNUAL JAN-FEB MAR-MAY JUN-SEP OCT-DEC
# 0  1901.0  25.42   20.11   27.64   28.16    23.1
# 1  1902.0  25.42   20.88   27.96   27.98   22.51
# 2  1903.0  25.01   19.99   27.02      28   22.33
# 3  1904.0  24.93   19.76   27.23   27.57   22.56
# 4  1905.0  24.84   18.36   26.38    28.2   23.13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     121 non-null    float64
#  1   ANNUAL   122 non-null    object
#  2   JAN-FEB  122 non-null    object
#  3   MAR-MAY  122 non-null    object
#  4   JUN-SEP  122 non-null    object
#  5   OCT-DEC  122 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 5.9+ KB

# %%
df.isnull().sum()
# Out:
# YEAR       2
# ANNUAL     1
# JAN-FEB    1
# MAR-MAY    1
# JUN-SEP    1
# OCT-DEC    1
# dtype: int64

# %% [markdown]
# No missing values found

# %%
df.head()
# Out:
#      YEAR ANNUAL JAN-FEB MAR-MAY JUN-SEP OCT-DEC
# 0  1901.0  25.42   20.11   27.64   28.16    23.1
# 1  1902.0  25.42   20.88   27.96   27.98   22.51
# 2  1903.0  25.01   19.99   27.02      28   22.33
# 3  1904.0  24.93   19.76   27.23   27.57   22.56
# 4  1905.0  24.84   18.36   26.38    28.2   23.13

# %%
df.tail()
# Out:
#        YEAR  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 118  2019.0   25.86    20.71       28     28.6    23.49
# 119  2020.0   25.78    20.79    27.58    28.45    23.75
# 120  2021.0   25.93    21.43    27.97    28.36    23.66
# 121     NaN     NaN      NaN      NaN      NaN      NaN
# 122     NaN  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     121 non-null    float64
#  1   ANNUAL   122 non-null    object
#  2   JAN-FEB  122 non-null    object
#  3   MAR-MAY  122 non-null    object
#  4   JUN-SEP  122 non-null    object
#  5   OCT-DEC  122 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 5.9+ KB

# %%
df.describe()
# Out:
#               YEAR
# count   121.000000
# mean   1961.000000
# std      35.073732
# min    1901.000000
# 25%    1931.000000
# 50%    1961.000000
# 75%    1991.000000
# max    2021.000000

# %%
df.groupby('YEAR')['ANNUAL'].mean()
# Out:
# YEAR
# 1901.0    25.42
# 1902.0    25.42
# 1903.0    25.01
# 1904.0    24.93
# 1905.0    24.84
#           ...
# 2017.0    26.04
# 2018.0    25.90
# 2019.0    25.86
# 2020.0    25.78
# 2021.0    25.93
# Name: ANNUAL, Length: 121, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[cols_to_convert].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Seasons and Annual Temperature")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='YEAR', y='ANNUAL', data=df, label='Annual')
plt.title("Annual Temperature Trend Over Years")
plt.xlabel("Year")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.show()
